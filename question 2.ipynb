# %%
# !pip install pylatexenc qiskit

# %%
from qiskit import QuantumCircuit
import numpy as np
from qiskit.quantum_info import Statevector

# %%
qc = QuantumCircuit(1)
qc.ry(1.40 , 0)
qc.rz(np.pi / 4,0)
qc.draw("mpl")

# %%
state = Statevector.from_circuit(qc)

# %%
alpha , beta = state.data # get values of alpha and beta

# %%
z = np.abs(a)**2 - np.abs(b)**2  #calculate expectation value

# %%
z   # expectation value 0.16 = 1/6 from question 1.
# Out:
# np.float64(0.16996714290024123)
